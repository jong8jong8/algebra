# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.arange(0, np.pi*2, 0.01)

# %%
y = np.sin(x)

# %%
plt.plot(x, y, 'c-.')
plt.xlabel("angle")
plt.ylabel("sine")
plt.title("sine wave")
# Out:
# Text(0.5, 1.0, 'sine wave')
